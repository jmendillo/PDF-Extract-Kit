# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id='opendatalab/pdf-extract-kit-1.0', local_dir='C:\\Users\\jmendillo\\miniconda3\\envs\\pdf-extract-kit-1.0', max_workers=20)
# Out:
# Fetching 177 files: 100%|██████████| 177/177 [02:17<00:00,  1.29it/s]
# 'C:\\Users\\jmendillo\\miniconda3\\envs\\pdf-extract-kit-1.0'

# %%
from modelscope import snapshot_download

snapshot_download(model_id='opendatalab/pdf-extract-kit-1.0', cache_dir='./')
# Out:
# ...
# 2025-11-18 13:30:47,770 - modelscope - INFO - Target directory already exists, skipping creation.
# './opendatalab\\pdf-extract-kit-1___0'

# %%
import paddleocr
from ppocr.utils.logging import get_logger
print("OK")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import paddleocr
#       2 from ppocr.utils.logging import get_logger
#       3 print("OK")
#
# File c:\Users\jmendillo\miniconda3\envs\pdf-extract-kit-1.0\lib\site-packages\paddleocr\__init__.py:15
#       1 # Copyright (c) 2025 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from paddlex.inference.utils.benchmark import benchmark
#      17 from ._models import (
#      18     ChartParsing,
#      19     DocImgOrientationClassification,
#    (...)
#      30     TextRecognition,
#      31 )
#      32 from ._pipelines import (
#      33     DocPreprocessor,
# ...
